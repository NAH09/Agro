# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as plt

# %% [markdown]
# Importation de base de données

# %%
df= pd.read_csv('C://Users//dell//Documents//draft//productionFruits.csv', sep=',')
df.isna().sum()
df.head()
# Out:
#   Code Domaine   Domaine  Code zone         Zone  Code Élément     Élément  \
# 0           QC  Cultures          2  Afghanistan          5510  Production
# 1           QC  Cultures          2  Afghanistan          5510  Production
# 2           QC  Cultures          2  Afghanistan          5510  Production
# 3           QC  Cultures          2  Afghanistan          5510  Production
# 4           QC  Cultures          2  Afghanistan          5510  Production
#
#    Code Produit    Produit  Code année  Année   Unité   Valeur Symbole  \
# 0           526   Abricots        2014   2014  tonnes  90000.0       F
# 1           526   Abricots        2015   2015  tonnes  87686.0     NaN
# 2           526   Abricots        2016   2016  tonnes  17894.0     NaN
# 3           558  Baies nda        2014   2014  tonnes  23561.0      Im
# 4           558  Baies nda        2015   2015  tonnes  24357.0      Im
#
#                               Description du Symbole
# 0                                     Estimation FAO
# 1                                  Donnée officielle
# 2                                  Donnée officielle
# 3  Données de la FAO basées sur une méthodologie ...
# 4  Données de la FAO basées sur une méthodologie ...

# %% [markdown]
# EXTRACTION DE LA BASE DE DONNEE DU SENEGAL

# %%
sen=df.loc[df['Code zone']==195 ,:]
sen
# Out:
#      Code Domaine   Domaine  Code zone     Zone  Code Élément     Élément  \
# 6492           QC  Cultures        195  Sénégal          5510  Production
# 6493           QC  Cultures        195  Sénégal          5510  Production
# 6494           QC  Cultures        195  Sénégal          5510  Production
# 6495           QC  Cultures        195  Sénégal          5510  Production
# 6496           QC  Cultures        195  Sénégal          5510  Production
# 6497           QC  Cultures        195  Sénégal          5510  Production
# 6498           QC  Cultures        195  Sénégal          5510  Production
# 6499           QC  Cultures        195  Sénégal          5510  Production
# 6500           QC  Cultures        195  Sénégal          5510  Production
# 6501           QC  Cultures        195  Sénégal          5510  Production
# 6502           QC  Cultures        195  Sénégal          5510  Production
# 6503           QC  Cultures        195  Sénégal          5510  Production
# 6504           QC  Cultures        195  Sénégal          5510  Production
# 6505           QC  Cultures        195  Sénégal          5510  Production
# 6506           QC  Cultures        195  Sénégal          5510  Production
# 6507           QC  Cultures        195  Sénégal          5510  Production
# 6508           QC  Cultures        195  Sénégal          5510  Production
# 6509           QC  Cultures        195  Sénégal          5510  Production
#
#       Code Produit                          Produit  Code année  Année  \
# 6492           486                          Bananes        2014   2014
# 6493           486                          Bananes        2015   2015
# 6494           486                          Bananes        2016   2016
# 6495           619                 Fruits frais nda        2014   2014
# 6496           619                 Fruits frais nda        2015   2015
# 6497           619                 Fruits frais nda        2016   2016
# 6498           603      Fruits tropicaux frais, nda        2014   2014
# 6499           603      Fruits tropicaux frais, nda        2015   2015
# 6500           603      Fruits tropicaux frais, nda        2016   2016
# 6501           571  Mangues, mangoustans et goyaves        2014   2014
# 6502           571  Mangues, mangoustans et goyaves        2015   2015
# 6503           571  Mangues, mangoustans et goyaves        2016   2016
# 6504           490                          Oranges        2014   2014
# 6505           490                          Oranges        2015   2015
# 6506           490                          Oranges        2016   2016
# 6507           567                        Pastèques        2014   2014
# 6508           567                        Pastèques        2015   2015
# 6509           567                        Pastèques        2016   2016
#
#        Unité    Valeur Symbole  \
# 6492  tonnes   35575.0     NaN
# 6493  tonnes   36500.0     NaN
# 6494  tonnes   37863.0      Im
# 6495  tonnes   36000.0     NaN
# 6496  tonnes   32246.0      Im
# 6497  tonnes   31801.0      Im
# 6498  tonnes   12853.0      Im
# 6499  tonnes   11447.0      Im
# 6500  tonnes   11587.0      Im
# 6501  tonnes  131000.0     NaN
# 6502  tonnes  125000.0     NaN
# 6503  tonnes  123606.0      Im
# 6504  tonnes   50000.0     NaN
# 6505  tonnes   50000.0     NaN
# 6506  tonnes   48869.0      Im
# 6507  tonnes  229267.0     NaN
# 6508  tonnes  270686.0     NaN
# 6509  tonnes  259225.0      Im
#
#                                  Description du Symbole
# 6492                                  Donnée officielle
# 6493                                  Donnée officielle
# 6494  Données de la FAO basées sur une méthodologie ...
# 6495                                  Donnée officielle
# 6496  Données de la FAO basées sur une méthodologie ...
# 6497  Données de la FAO basées sur une méthodologie ...
# 6498  Données de la FAO basées sur une méthodologie ...
# 6499  Données de la FAO basées sur une méthodologie ...
# 6500  Données de la FAO basées sur une méthodologie ...
# 6501                                  Donnée officielle
# 6502                                  Donnée officielle
# 6503  Données de la FAO basées sur une méthodologie ...
# 6504                                  Donnée officielle
# 6505                                  Donnée officielle
# 6506  Données de la FAO basées sur une méthodologie ...
# 6507                                  Donnée officielle
# 6508                                  Donnée officielle
# 6509  Données de la FAO basées sur une méthodologie ...
